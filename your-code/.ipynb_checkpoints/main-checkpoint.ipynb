# %% [markdown]
# # List Comprehensions Lab
#
# Complete the following set of exercises to solidify your knowledge of list comprehensions.

# %%
import os
import numpy as np
import pandas as pd

# %% [markdown]
# ### 1. Use a list comprehension to create and print a list of consecutive integers starting with 1 and ending with 50.

# %%
list_50 = [x for x in range(51)]

# %% [markdown]
# ### 2. Use a list comprehension to create and print a list of even numbers starting with 2 and ending with 200.

# %%
list_200 = [x for x in range(200) if x%2==0]

# %% [markdown]
# ### 3. Use a list comprehension to create and print a list containing all elements of the 10 x 4 Numpy array below.

# %%
a = np.array([[0.84062117, 0.48006452, 0.7876326 , 0.77109654],
       [0.44409793, 0.09014516, 0.81835917, 0.87645456],
       [0.7066597 , 0.09610873, 0.41247947, 0.57433389],
       [0.29960807, 0.42315023, 0.34452557, 0.4751035 ],
       [0.17003563, 0.46843998, 0.92796258, 0.69814654],
       [0.41290051, 0.19561071, 0.16284783, 0.97016248],
       [0.71725408, 0.87702738, 0.31244595, 0.76615487],
       [0.20754036, 0.57871812, 0.07214068, 0.40356048],
       [0.12149553, 0.53222417, 0.9976855 , 0.12536346],
       [0.80930099, 0.50962849, 0.94555126, 0.33364763]])

# %%
arr_4 = np.array([[np.random.rand()for i in range(4)] for i in range(10)])
# Out:
# array([[0.73262276, 0.25194268, 0.40004011, 0.24903295],
#        [0.64653223, 0.13857678, 0.13882645, 0.99873239],
#        [0.41865428, 0.663546  , 0.57644605, 0.75003285],
#        [0.92186154, 0.52674469, 0.05157011, 0.51672423],
#        [0.12633821, 0.03216985, 0.19045317, 0.70283424],
#        [0.67120477, 0.33281962, 0.1318158 , 0.42020928],
#        [0.89528525, 0.54456356, 0.52976624, 0.64817385],
#        [0.68530481, 0.59656613, 0.82963674, 0.6417523 ],
#        [0.48063185, 0.06707733, 0.91159141, 0.97120771],
#        [0.14549729, 0.86433548, 0.46199825, 0.46054221]])

# %% [markdown]
# ### 4. Add a condition to the list comprehension above so that only values greater than or equal to 0.5 are printed.

# %%
[[np.random.rand()for i in range(4) if i > 0.5] for i in range(10)]
# Out:
# [[0.918312403798282, 0.43973126118061234, 0.027062466433047883],
#  [0.45374146203466037, 0.7370329508023519, 0.4583287400147068],
#  [0.3664988384396477, 0.7712917802537769, 0.969222507563726],
#  [0.8337805767475089, 0.9268111918100692, 0.3598066894240126],
#  [0.7686132908897453, 0.926289670245065, 0.596271321397373],
#  [0.6911557908180436, 0.04148882771747375, 0.6014774668515165],
#  [0.9292723608521055, 0.15438948745296055, 0.5509954222268242],
#  [0.39614460418417763, 0.8427412709061524, 0.3296670154604342],
#  [0.7946107653452745, 0.24481575797882504, 0.5917315531917372],
#  [0.3840384564587853, 0.5227482321671206, 0.21106253683445975]]

# %% [markdown]
# ### 5. Use a list comprehension to create and print a list containing all elements of the 5 x 2 x 3 Numpy array below.

# %%
b = np.array([[[0.55867166, 0.06210792, 0.08147297],
        [0.82579068, 0.91512478, 0.06833034]],

       [[0.05440634, 0.65857693, 0.30296619],
        [0.06769833, 0.96031863, 0.51293743]],

       [[0.09143215, 0.71893382, 0.45850679],
        [0.58256464, 0.59005654, 0.56266457]],

       [[0.71600294, 0.87392666, 0.11434044],
        [0.8694668 , 0.65669313, 0.10708681]],

       [[0.07529684, 0.46470767, 0.47984544],
        [0.65368638, 0.14901286, 0.23760688]]])

# %%
nested = np.array([[[np.random.rand()for i in range(3)]for i in range(2)] for i in range(5)])
nested
# Out:
# array([[[0.24757084, 0.14202846, 0.18509456],
#         [0.31444537, 0.57439525, 0.27355339]],
#
#        [[0.76960547, 0.38436068, 0.41338015],
#         [0.45881004, 0.75061613, 0.75107363]],
#
#        [[0.30023274, 0.93114789, 0.0611831 ],
#         [0.96010917, 0.3100279 , 0.06789362]],
#
#        [[0.15899228, 0.04718021, 0.01124224],
#         [0.83256008, 0.80846077, 0.957542  ]],
#
#        [[0.95399351, 0.35242174, 0.62143846],
#         [0.02125027, 0.4365823 , 0.84295906]]])

# %% [markdown]
# ### 5. Add a condition to the list comprehension above so that the last value in each subarray is printed, but only if it is less than or equal to 0.5.

# %%
np.random.seed(10)
nested = np.array([[[np.random.rand()for a in range(3)if a < 0.5][-1]for e in range(2)] for r in range(5)])
nested
# Out:
# array([[[0.77132064, 0.02075195, 0.63364823],
#         [0.74880388, 0.49850701, 0.22479665]],
#
#        [[0.19806286, 0.76053071, 0.16911084],
#         [0.08833981, 0.68535982, 0.95339335]],
#
#        [[0.00394827, 0.51219226, 0.81262096],
#         [0.61252607, 0.72175532, 0.29187607]],
#
#        [[0.91777412, 0.71457578, 0.54254437],
#         [0.14217005, 0.37334076, 0.67413362]],
#
#        [[0.44183317, 0.43401399, 0.61776698],
#         [0.51313824, 0.65039718, 0.60103895]]])

# %% [markdown]
# ### 6. Use a list comprehension to select and print the names of all CSV files in the */data* directory.

# %%
names = [i for i in os.listdir('../data')]
names
# Out:
# ['sample_file_0.csv',
#  'sample_file_0.txt',
#  'sample_file_1.csv',
#  'sample_file_1.txt',
#  'sample_file_2.csv',
#  'sample_file_2.txt',
#  'sample_file_3.csv',
#  'sample_file_3.txt',
#  'sample_file_4.csv',
#  'sample_file_4.txt',
#  'sample_file_5.csv',
#  'sample_file_5.txt',
#  'sample_file_6.csv',
#  'sample_file_6.txt',
#  'sample_file_7.csv',
#  'sample_file_7.txt',
#  'sample_file_8.csv',
#  'sample_file_8.txt',
#  'sample_file_9.csv',
#  'sample_file_9.txt']

# %% [markdown]
# ### 7. Use a list comprehension and the Pandas `read_csv` and `concat` methods to read all CSV files in the */data* directory and combine them into a single data frame. Display the top 10 rows of the resulting data frame.

# %%
l_df = pd.concat([pd.read_csv('../data/'+i) for i in names])
l_df.head(10)
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.734751  0.195362  0.734309  0.598184  0.763433  0.263434  0.868066
# 1  0.772607  0.445391  0.249642  0.787922  0.598583  0.827238  0.624126
# 2  0.226428  0.268764  0.694262  0.622335  0.063843  0.122683  0.815625
# 3  0.362748  0.495430  0.113876  0.594149  0.612522  0.625204  0.864050
# 4  0.033415  0.340433  0.464971  0.363737  0.025815  0.434129  0.415163
# 0  0.734751  0.195362  0.734309  0.598184  0.763433  0.263434  0.868066
# 1  0.772607  0.445391  0.249642  0.787922  0.598583  0.827238  0.624126
# 2  0.226428  0.268764  0.694262  0.622335  0.063843  0.122683  0.815625
# 3  0.362748  0.495430  0.113876  0.594149  0.612522  0.625204  0.864050
# 4  0.033415  0.340433  0.464971  0.363737  0.025815  0.434129  0.415163
#
#           7         8         9        10        11        12        13  \
# 0  0.058092  0.753502  0.587513  0.311608  0.178356  0.182922  0.147631
# ...

# %% [markdown]
# ### 8. Use a list comprehension to select and print the column numbers for columns from the data set whose median is less than 0.48.

# %%
num = [col for col in l_df.columns if l_df[col].median() < 0.48]

# %%
num
# Out:
# ['2', '9', '12', '14', '17']

# %% [markdown]
# ### 9. Use a list comprehension to add a new column (20) to the data frame whose values are the values in column 19 minus 0.1. Display the top 10 rows of the resulting data frame.

# %%
l_df['20'] = [a-0.1 for a in l_df['19']]
l_df.head(10)
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.734751  0.195362  0.734309  0.598184  0.763433  0.263434  0.868066
# 1  0.772607  0.445391  0.249642  0.787922  0.598583  0.827238  0.624126
# 2  0.226428  0.268764  0.694262  0.622335  0.063843  0.122683  0.815625
# 3  0.362748  0.495430  0.113876  0.594149  0.612522  0.625204  0.864050
# 4  0.033415  0.340433  0.464971  0.363737  0.025815  0.434129  0.415163
# 0  0.734751  0.195362  0.734309  0.598184  0.763433  0.263434  0.868066
# 1  0.772607  0.445391  0.249642  0.787922  0.598583  0.827238  0.624126
# 2  0.226428  0.268764  0.694262  0.622335  0.063843  0.122683  0.815625
# 3  0.362748  0.495430  0.113876  0.594149  0.612522  0.625204  0.864050
# 4  0.033415  0.340433  0.464971  0.363737  0.025815  0.434129  0.415163
#
#           7         8         9  ...        11        12        13        14  \
# 0  0.058092  0.753502  0.587513  ...  0.178356  0.182922  0.147631  0.391188
# ...

# %% [markdown]
# ### 10. Use a list comprehension to extract and print all values from the data set that are between 0.7 and 0.75.

# %%
bwt = [a for a in i for i in l_df.values if (a>0.7)&(a<0.75)]

# %%
for i in l_df.values:
    for a in i:
        if (a>0.7)&(a<0.75):
            print(a)
# Out:
# 0.7347510852128797
# 0.7343092314001137
# 0.7490680818183477
# 0.7390312927111312
# 0.7159290265157912
# 0.7347510852128797
# 0.7343092314001137
# 0.7490680818183477
# 0.7390312927111312
# 0.7159290265157912
# 0.7356923324968598
# 0.7357618655811269
# 0.7306642125209889
# 0.7356923324968598
# 0.7357618655811269
# 0.7306642125209889
# 0.7033930409580709
# 0.7013619954419494
# 0.7396561066717461
# 0.7033930409580709
# 0.7013619954419494
# 0.7396561066717461
# 0.7045750112959754
# 0.7045750112959754
# 0.7383982036983279
# 0.7178166705957928
# 0.7088042362916818
# 0.7374449181749492
# 0.7264121114538001
# 0.7133695725698419
# 0.7383982036983279
# 0.7178166705957928
# 0.7088042362916818
# 0.7374449181749492
# 0.7264121114538001
# 0.7133695725698419
# 0.7476323136755818
# 0.7268545088531969
# 0.7111584953876777
# 0.7008930873050235
# 0.7209375615129192
# 0.7303553716733908
# 0.7274869207330491
# 0.7476323136755818
# 0.7268545088531969
# 0.7111584953876777
# 0.7008930873050235
# ...
